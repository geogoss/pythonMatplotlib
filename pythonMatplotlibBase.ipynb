# %%
# graphique -> mieux comprendre le problème sur lequel on travaille en visualisant les data
import numpy as np

# %%
x = np.linspace(0, 2, 10)
y = x**2
print(x)
# Out:
# [0.         0.22222222 0.44444444 0.66666667 0.88888889 1.11111111
#  1.33333333 1.55555556 1.77777778 2.        ]

# %% [markdown]
# 1) pyplot

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x, y)
plt.show()

# %%
plt.scatter(x, y)
plt.show()

# %% [markdown]
# ![image.png](attachment:a239e264-c3b1-4aed-b802-7446eab690db.png)

# %% [markdown]
# cycle de vie d'une figure avec matplotlib

# %% [markdown]
# ![image.png](attachment:d5522d8b-f06d-45ff-8f35-6f22ff041dd9.png)

# %% [markdown]
# ![image.png](attachment:58ade758-9570-4245-b80e-932a310b9773.png)

# %% [markdown]
# ![image.png](attachment:5cae21a1-7df6-4c82-84f7-743f7bf7cd49.png)

# %% [markdown]
# ![image.png](attachment:bc041c17-7723-4a2b-9c1d-e93677816ef6.png)
